# %% [markdown]
# # 9 Improving performance

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Learning curves

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
X, y = digits.data, digits.target

# %%
X[0]
# Out:
# array([  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.,   0.,   0.,  13.,
#         15.,  10.,  15.,   5.,   0.,   0.,   3.,  15.,   2.,   0.,  11.,
#          8.,   0.,   0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.,   0.,
#          5.,   8.,   0.,   0.,   9.,   8.,   0.,   0.,   4.,  11.,   0.,
#          1.,  12.,   7.,   0.,   0.,   2.,  14.,   5.,  10.,  12.,   0.,
#          0.,   0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.])

# %%
X.shape
# Out:
# (1797, 64)

# %%
for i in range(8):
    plt.subplot(1,8,i+1)
    plt.imshow(X.reshape(-1, 8, 8)[i], cmap='gray')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import keras.backend as K
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
K.clear_session()

# %%
model = Sequential()
model.add(Dense(16, input_shape=(64,), activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile('adam', 'categorical_crossentropy', metrics=['accuracy'])

# %%
# store the initial random weights
initial_weights = model.get_weights()

# %%
y_cat = to_categorical(y, 10)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_cat,
                                                    test_size=0.3)

# %%
X_train.shape
# Out:
# (1257, 64)

# %%
train_sizes = (len(X_train) * np.linspace(0.1, 0.999, 4)).astype(int)
train_sizes
# Out:
# array([ 125,  502,  879, 1255])

# %%
train_scores = []
test_scores = []

for train_size in train_sizes:
    X_train_frac, _, y_train_frac, _ = \
    train_test_split(X_train, y_train, train_size=train_size)
    
    # at each iteration reset the weights of the model
    # to the initial random weights
    model.set_weights(initial_weights)
    
    h = model.fit(X_train_frac, y_train_frac,
                  verbose=0,
                  epochs=300,
                  callbacks=[EarlyStopping(monitor='loss', patience=1)])

    r = model.evaluate(X_train_frac, y_train_frac, verbose=0)
    train_scores.append(r[-1])
    
    e = model.evaluate(X_test, y_test, verbose=0)
    test_scores.append(e[-1])
    
    print("Done size: ", train_size)
# Out:
# Done size:  125
# Done size:  502
# Done size:  879
# Done size:  1255

# %%
plt.plot(train_sizes, train_scores, 'o-', label="Training score")
plt.plot(train_sizes, test_scores, 'o-', label="Test score")
plt.legend(loc="best")

# %% [markdown]
# ## Batch Normalization

# %%
from keras.layers import BatchNormalization

# %%
def repeated_training(X_train,
                      y_train,
                      X_test,
                      y_test,
                      units=512,
                      activation='sigmoid',
                      optimizer='sgd',
                      do_bn=False,
                      epochs=10,
                      repeats=3):
    histories = []
    
    for repeat in range(repeats):
        K.clear_session()

        model = Sequential()
        
        # first fully connected layer
        model.add(Dense(units,
                        input_shape=X_train.shape[1:],
                        kernel_initializer='normal',
                        activation=activation))
        if do_bn:
            model.add(BatchNormalization())

        # second fully connected layer
        model.add(Dense(units,
                        kernel_initializer='normal',
                        activation=activation))
        if do_bn:
            model.add(BatchNormalization())

        # third fully connected layer
        model.add(Dense(units,
                        kernel_initializer='normal',
                        activation=activation))
        if do_bn:
            model.add(BatchNormalization())

        # output layer
        model.add(Dense(10, activation='softmax'))
        
        model.compile(optimizer,
                      'categorical_crossentropy',
                      metrics=['accuracy'])

        h = model.fit(X_train, y_train,
                      validation_data=(X_test, y_test),
                      epochs=epochs,
                      verbose=0)
        histories.append([h.history['acc'], h.history['val_acc']])
        print(repeat, end=' ')

    histories = np.array(histories)
    
    # calculate mean and standard deviation across repeats:
    mean_acc = histories.mean(axis=0)
    std_acc = histories.std(axis=0)
    print()
    
    return mean_acc[0], std_acc[0], mean_acc[1], std_acc[1]

# %%
mean_acc, std_acc, mean_acc_val, std_acc_val = \
    repeated_training(X_train, y_train, X_test, y_test, do_bn=False, epochs=30)
# Out:
# 0 1 2

# %%
mean_acc_bn, std_acc_bn, mean_acc_val_bn, std_acc_val_bn = \
    repeated_training(X_train, y_train, X_test, y_test, do_bn=True, epochs=30)
# Out:
# 0 1 2

# %%
def plot_mean_std(m, s):
    plt.plot(m)
    plt.fill_between(range(len(m)), m-s, m+s, alpha=0.1)

# %%
plot_mean_std(mean_acc, std_acc)
plot_mean_std(mean_acc_val, std_acc_val)
plot_mean_std(mean_acc_bn, std_acc_bn)
plot_mean_std(mean_acc_val_bn, std_acc_val_bn)
plt.ylim(0, 1.01)
plt.title("Batch Normalization Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test', 'Train with Batch Normalization', 'Test with Batch Normalization'], loc='best')

# %% [markdown]
# ## Weight Regularization & Dropout

# %%
from keras.layers import Dropout

# %%
model = Sequential()
model.add(Dropout(0.2, input_shape=X_train.shape[1:]))
# first fully connected layer
model.add(Dense(512, kernel_initializer='normal',
                kernel_regularizer='l2', activation='sigmoid'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.compile('sgd',
              'categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

generator = ImageDataGenerator(rescale = 1./255,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               rotation_range = 20,
                               shear_range = 0.3,
                               zoom_range = 0.3,
                               horizontal_flip = True)

# %%
train = generator.flow_from_directory('../data/generator',
                                      target_size = (128, 128),
                                      batch_size = 32,
                                      class_mode = 'binary')
# Out:
# Found 1 images belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(16):
    img, label = train.next()
    plt.subplot(4, 4, i+1)
    plt.imshow(img[0])

# %% [markdown]
# ## Embeddings

# %%
from keras.layers import Embedding

# %%
model = Sequential()
model.add(Embedding(input_dim=100, output_dim=2))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 2)           200
# =================================================================
# Total params: 200
# Trainable params: 200
# Non-trainable params: 0
# _________________________________________________________________

# %%
emb = model.predict(np.array([[81,  1, 96, 79],
                              [17, 47, 69, 50],
                              [49,  3, 12, 88]]))

# %%
emb.shape
# Out:
# (3, 4, 2)

# %%
emb
# Out:
# array([[[-0.0238085 , -0.04914343],
#         [ 0.03641412, -0.04202265],
#         [ 0.04067326, -0.01820772],
#         [ 0.02382376, -0.00335461]],
#
#        [[-0.03826135, -0.04985467],
#         [-0.04168274, -0.00156677],
#         [ 0.02573637,  0.03632111],
#         [ 0.0428731 , -0.01142895]],
#
#        [[-0.02859279, -0.01308081],
#         [ 0.03487727,  0.0083292 ],
#         [ 0.03475806,  0.01565218],
#         [-0.00153106,  0.0301085 ]]], dtype=float32)

# %% [markdown]
# ## Sentiment prediction on movie Reviews

# %%
from keras.datasets import imdb

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data('/tmp/imdb.npz',
                                                      num_words=None,
                                                      skip_top=0,
                                                      maxlen=None,
                                                      start_char=1,
                                                      oov_char=2,
                                                      index_from=3)
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz

# %%
X_train.shape
# Out:
# (25000,)

# %%
X_train[1]
# Out:
# [1,
#  194,
#  1153,
#  194,
#  8255,
#  78,
#  228,
#  5,
#  6,
#  1463,
#  4369,
#  5012,
#  134,
#  26,
#  4,
#  715,
#  8,
#  118,
#  1634,
#  14,
#  394,
#  20,
#  13,
#  119,
#  954,
#  189,
#  102,
#  5,
#  207,
#  110,
#  3103,
#  21,
#  14,
#  69,
#  188,
#  8,
#  30,
#  23,
#  7,
#  4,
#  249,
#  126,
#  93,
#  4,
#  114,
#  9,
#  2300,
#  1523,
#  5,
#  647,
#  4,
#  116,
#  9,
#  35,
#  8163,
#  4,
#  229,
#  9,
#  340,
#  1322,
#  4,
#  118,
#  9,
#  4,
#  130,
#  4901,
#  19,
#  4,
#  1002,
#  5,
#  89,
#  29,
#  952,
#  46,
#  37,
#  4,
#  455,
#  9,
#  45,
#  43,
#  38,
#  1543,
#  1905,
#  398,
#  4,
#  1649,
#  26,
#  6853,
#  5,
#  163,
#  11,
#  3215,
#  10156,
#  4,
#  1153,
#  9,
#  194,
#  775,
#  7,
#  8255,
#  11596,
#  349,
#  2637,
#  148,
#  605,
#  15358,
#  8003,
#  15,
#  123,
#  125,
#  68,
#  23141,
#  6853,
#  15,
#  349,
#  165,
#  4362,
#  98,
#  5,
#  4,
#  228,
#  9,
#  43,
#  36893,
#  1157,
#  15,
#  299,
#  120,
#  5,
#  120,
#  174,
#  11,
#  220,
#  175,
#  136,
#  50,
#  9,
#  4373,
#  228,
#  8255,
#  5,
#  25249,
#  656,
#  245,
#  2350,
#  5,
#  4,
#  9837,
#  131,
#  152,
#  491,
#  18,
#  46151,
#  32,
#  7464,
#  1212,
#  14,
#  9,
#  6,
#  371,
#  78,
#  22,
#  625,
#  64,
#  1382,
#  9,
#  8,
#  168,
#  145,
#  23,
#  4,
#  1690,
#  15,
#  16,
#  4,
#  1355,
#  5,
#  28,
#  6,
#  52,
#  154,
#  462,
#  33,
#  89,
#  78,
#  285,
#  16,
#  145,
#  95]

# %%
idx = imdb.get_word_index()

# %%
max(idx.values())
# Out:
# 88584

# %%
idx
# Out:
# {'bagatelle': 51365,
#  "mode'": 78465,
#  'tsanders': 66012,
#  'dissapointment': 29030,
#  "theatre's": 37246,
#  'simulator': 38677,
#  'uncalled': 26502,
#  'downhill': 4448,
#  'gown': 11186,
#  'informations': 51837,
#  'squealing': 25004,
#  'soaps': 13163,
#  'plasticized': 63300,
#  'senseless': 4268,
#  "clockwatchers'": 61675,
#  'higly': 81957,
#  'skyward': 32067,
#  'ganzel': 30691,
#  'buddhas': 77911,
#  'bigardo': 44002,
#  "roof'": 55854,
#  "europe'": 43485,
#  'woodeness': 61087,
#  "com'": 51759,
#  'sliced': 14389,
#  'spud': 49078,
#  'bioterrorism': 41569,
#  'chen': 10267,
#  'violet': 14357,
#  'inappropriate': 4647,
#  'ichii': 52234,
#  "dorothy's": 31024,
#  'constructed': 4478,
#  "rigg's": 65766,
#  "schmid's": 29823,
#  'faye': 8367,
#  'chancellor': 26802,
#  'interpreting': 23629,
#  'trent': 11339,
#  'conceited': 17579,
#  'gothic': 3357,
#  'catscratch': 24952,
#  'mantels': 61062,
#  'payments': 20673,
#  'wilbur': 46401,
#  "aaron'": 61288,
#  'lousing': 67367,
#  'labyrinths': 60195,
#  'vcrs': 27794,
#  'messianic': 81416,
#  'shriek': 13428,
#  'dubiel': 76199,
#  'aronofsky': 39879,
#  'airy': 75849,
#  'braininess': 47632,
#  "'specialist": 71301,
#  'gunnarsson': 45721,
#  "frank's": 25614,
#  'bluto': 43461,
#  "nelson's": 20800,
#  'imperioli': 21066,
#  'intermarriage': 67066,
#  'thriteen': 50309,
#  'perished': 21926,
#  'disturbance': 19496,
#  'expertise': 9767,
#  'charictor': 77755,
#  'inn': 12518,
#  'niece': 6325,
#  'endeavoring': 42162,
#  'softfordigging': 66700,
#  'intensities': 67429,
#  'heatbeats': 74825,
#  'impaling': 30670,
#  "barjatya's": 29057,
#  'rushmore': 24542,
#  "stefan's": 44280,
#  'gabe': 12359,
#  'rohleder': 81601,
#  'underestimates': 65755,
#  "samurai's": 49762,
#  "'adventures'": 59915,
#  'genèvieve': 82413,
#  'likeable': 7202,
#  "anton's": 38077,
#  'aileen': 19313,
#  'deedlit': 33606,
#  "her's": 23268,
#  'obote': 68396,
#  'donger': 70417,
#  'mesmerization': 78717,
#  "hallan's": 64925,
#  'foresees': 76389,
#  'caller': 18455,
#  'izod': 77868,
#  'eastwoods': 70636,
#  'gushes': 30269,
#  "koenekamp's": 86782,
#  'musashibo': 81987,
#  "ratner's": 77312,
#  'gladstone': 36647,
#  "school'": 25829,
#  'iq': 7492,
#  'chordant': 80122,
#  'phibes': 26600,
#  'descents': 41144,
#  'parallax': 32021,
#  'kalmus': 72346,
#  'analogical': 53418,
#  'parasol': 42651,
#  'skepticism': 16833,
#  'lesley': 16974,
#  'dedicating': 49515,
#  'marriages': 10234,
#  'clucking': 79288,
#  "fetisov's": 58793,
#  'doubt': 821,
#  'aphoristic': 64830,
#  'watcheable': 63042,
#  'voyage': 6658,
#  'horseman': 51187,
#  'daninsky': 17209,
#  'preston': 5362,
#  'imbd': 51774,
#  'forsaken': 13068,
#  'wierder': 61659,
#  'stoppard': 79523,
#  "media'": 68399,
#  'pressed': 7366,
#  'renewing': 58017,
#  'defining': 7824,
#  'barbarash': 41006,
#  'babyy': 73423,
#  'glamourizing': 68706,
#  'movement': 2422,
#  'popular': 1060,
#  'cloverfield': 31633,
#  'mullets': 23872,
#  '236': 61185,
#  'rapping': 15092,
#  'crossovers': 35378,
#  'fetus': 20222,
#  'woodenly': 32200,
#  'cate': 15211,
#  'counterbalancing': 45271,
#  'sneeze': 33960,
#  'boyer': 6540,
#  "cure'": 59469,
#  '2200': 36050,
#  'complication': 19228,
#  "'oliver": 62131,
#  'herbal': 31274,
#  "leaders'": 72731,
#  "o'rourke": 61020,
#  'manu': 20932,
#  'renovating': 33254,
#  'thenceforward': 65210,
#  'footprints': 51236,
#  'lycéens': 73318,
#  'implicate': 26322,
#  'levered': 82159,
#  'daria': 8640,
#  'wesker': 68410,
#  'meteor': 7107,
#  'embalmed': 50205,
#  'dusan': 42680,
#  'watched': 293,
#  'entrusted': 25931,
#  'mélanie': 80502,
#  'pharagraph': 70656,
#  'glockenspur': 58505,
#  'mchmaon': 82525,
#  'squeeing': 66843,
#  'gangbanger': 40707,
#  'pliers': 25837,
#  'treasury': 15537,
#  'valleyspeak': 57162,
#  "soilders'": 53760,
#  'doubters': 84140,
#  'sparrows': 43493,
#  'chronically': 24566,
#  'fend': 14044,
#  "'raiders": 71260,
#  'lease': 14280,
#  "'george'": 86500,
#  'slices': 16394,
#  "walston's": 87615,
#  'buffoon': 11120,
#  'rodder': 34980,
#  'thesinger': 44230,
#  'anywhoo': 58120,
#  'thorssen': 68616,
#  'vikki': 69054,
#  'shitty': 17857,
#  'austreim': 75731,
#  "governor's": 37940,
#  'elephant': 4488,
#  "'joshua": 75827,
#  'futon': 62341,
#  'arty': 7109,
#  'adolfo': 86575,
#  'distract': 6678,
#  'frosty': 12026,
#  'louche': 32341,
#  'chalk': 10295,
#  'cordially': 36996,
#  'wildenbrück': 63945,
#  'muito': 61084,
#  'laurdale': 66352,
#  'cope': 5584,
#  'ropers': 49254,
#  "payne'": 58627,
#  'ogend': 65856,
#  'hassle': 22255,
#  "loggia's": 82904,
#  "slide's": 79784,
#  'rather': 244,
#  'enjolras': 39148,
#  '1952': 10162,
#  'exhibitions': 26014,
#  'comb': 30215,
#  'indecisive': 22451,
#  'chinned': 86172,
#  'peeps': 39903,
#  'sparkles': 17417,
#  'preach': 10967,
#  'apaches': 44783,
#  'intruding': 23901,
#  "'03": 32859,
#  'us\x97still': 74563,
#  'hepton': 26346,
#  "imax's": 51053,
#  "'ritin'": 72702,
#  'benefices': 33553,
#  "annie's": 53145,
#  'cultivation': 59147,
#  'bark': 29079,
#  "voorhees'": 88583,
#  'microfiche': 33403,
#  'blackbird': 87241,
#  'puertorican': 30555,
#  'alyssa': 62644,
#  'accessible': 6337,
#  'diagnosis': 16007,
#  'vivid': 3980,
#  'speedo': 60935,
#  "enough's": 74380,
#  'falsehoods': 36213,
#  'sweats': 23419,
#  'hippies': 7283,
#  'nekkid': 23528,
#  'extraterrestrials': 41520,
#  'stefano': 28077,
#  'pressured': 20923,
#  'headsets': 61386,
#  'sears': 34043,
#  "'snuff": 46199,
#  'loosely': 3745,
#  'typecasted': 72101,
#  "'napoleon": 47545,
#  'maddin': 23533,
#  "kipling's": 17966,
#  'kassovitz': 31345,
#  'styx': 35411,
#  'remorselessness': 64628,
#  'whippet': 40317,
#  'tudsbury': 76090,
#  'omissions': 21118,
#  'harvester': 31226,
#  'prophesizes': 55582,
#  'pancreas': 47789,
#  'qld': 86871,
#  'governement': 57430,
#  'reductive': 60015,
#  'biswas': 38453,
#  'vault': 9375,
#  'reg': 22242,
#  'blackfriars': 63975,
#  'mascots': 82677,
#  'hawthorne': 21775,
#  'kangwon': 22161,
#  'servers': 50784,
#  'nora': 8779,
#  'centerers': 76151,
#  'patron': 13371,
#  'city': 540,
#  'warriors': 5194,
#  'authenticity': 6304,
#  'annette': 16593,
#  'ridden': 4752,
#  'pianful': 81869,
#  'lounges': 40568,
#  'cogan': 37931,
#  'chubbiness': 83347,
#  "myron's": 80119,
#  'hlots': 39342,
#  "clutter's": 38206,
#  'ipod': 28282,
#  'malik': 14870,
#  'milbrant': 53317,
#  'passworthys': 77241,
#  'horn': 8738,
#  'vomits': 52443,
#  'anticlimatic': 65189,
#  'matras': 52301,
#  'crapola': 37106,
#  'flexibility': 27948,
#  'instigate': 84362,
#  'filthier': 75206,
#  'attributing': 87907,
#  'strongbox': 61535,
#  'control': 1137,
#  'cupido': 76202,
#  "signalman'": 62523,
#  'ropier': 66947,
#  'sidetracked': 29611,
#  'infamy': 25057,
#  'warns': 7129,
#  "'fight": 46359,
#  'wardrobe': 6136,
#  'rav': 69276,
#  'misogynist': 26737,
#  'deficiency': 32716,
#  "blitzstein's": 34951,
#  'tron': 23569,
#  'tuvok': 25740,
#  'biospheres': 61224,
#  'bingle': 58696,
#  'jehan': 77616,
#  'eliminating': 15854,
#  'schoolgirls': 39632,
#  'ain´t': 42301,
#  'sinais': 82205,
#  'johnnie': 15832,
#  'aids': 4419,
#  'sushma': 72769,
#  'ladies': 1911,
#  'perfection': 3200,
#  'huck': 36369,
#  'cortez': 9602,
#  'elope': 46384,
#  'dislocate': 49866,
#  'gash': 31288,
#  'stubborness': 42707,
#  'immortalized': 22329,
#  'helplessness': 14804,
#  "ochiai's": 54382,
#  'calculatedly': 69996,
#  'ranch': 7030,
#  'contagonists': 52991,
#  "'raoul": 64340,
#  'lengthened': 70688,
#  'spells': 8627,
#  '\x97and': 51481,
#  'switchblade': 30429,
#  '1923': 75067,
#  'crispins': 70306,
#  'erotic': 2472,
#  "'i'll": 29652,
#  'streetcar': 13876,
#  'hurray': 47628,
#  "doodlebop's": 71738,
#  'sportsmanship': 46597,
#  "kei's": 40671,
#  'mcdermott': 9202,
#  'claws': 18631,
#  'instalments': 40184,
#  'rootboy': 72705,
#  "d'tat": 56072,
#  'baguettes': 55876,
#  'cochran': 49699,
#  "'recording'": 77926,
#  'thiessen': 26810,
#  'horrendousness': 60680,
#  'eros': 27500,
#  'landons': 69087,
#  "austin's": 35922,
#  'pinched': 27983,
#  'windman': 27978,
#  'zwartboek': 64648,
#  'lifeforms': 43363,
#  'brainpower': 82562,
#  'semite': 35791,
#  "yours'": 65452,
#  'yard': 5039,
#  'prfessionalism': 72824,
#  'moseley': 53896,
#  'quinton': 55193,
#  'illustrator': 25345,
#  'schürer': 38253,
#  'brulier': 63680,
#  'mesa': 48824,
#  'zionism': 82782,
#  'macfadyen': 71579,
#  'jackson': 1878,
#  'clifton': 20756,
#  'bukhanovsky': 39897,
#  "moment'": 35662,
#  'hodge': 14086,
#  '428': 64624,
#  'yugoslavian': 32712,
#  "honesty'": 79429,
#  'warlord': 13231,
#  'nonstraight': 62485,
#  'raghava': 85517,
#  "mobsters'": 42451,
#  'redwood': 46206,
#  'millinium': 60576,
#  'scottland': 62463,
#  'rn': 63537,
#  'zanjeer': 52764,
#  'ekta': 71739,
#  "feminists'": 59976,
#  'albatross': 79740,
#  'interplanetary': 67709,
#  'rum': 31307,
#  'carvan': 87355,
#  'little\x85off': 60597,
#  'awe': 4296,
#  'paré': 58068,
#  'disperses': 57815,
#  'univesity': 72382,
#  'politicians': 7268,
#  'wedged': 28137,
#  'dissension': 66153,
#  'edges': 8112,
#  'insupportable': 87364,
#  'didactic': 15677,
#  'disco': 7506,
#  'settles': 12834,
#  'cathay': 77653,
#  'orphee': 58096,
#  "'henry'": 55701,
#  'mathematical': 18819,
#  'dweezil': 84931,
#  "'mac'": 78230,
#  'wreathed': 58960,
#  'admitted': 6996,
#  'ribbon': 32438,
#  'prosperity': 23357,
#  'assuming': 5680,
#  'bingen': 71249,
#  'hoyt': 24975,
#  'bachlor': 53639,
#  'romanticized': 13922,
#  'literalism': 74954,
#  'mantis': 78025,
#  'requisite': 9568,
#  'muting': 45563,
#  "exploration'": 85089,
#  "hare's": 67984,
#  'marta': 30697,
#  'whaaaaa': 65850,
#  'nagiko': 45051,
#  'occupies': 17393,
#  'kristoffer': 44604,
#  'unrevealing': 86794,
#  'cluny': 86563,
#  'relevation': 43941,
#  '1990s': 5971,
#  'lena': 4568,
#  'ow': 22270,
#  'caused': 2161,
#  'packenham': 70465,
#  "podalydes'": 74458,
#  'persepolis': 36437,
#  'wip': 40009,
#  'edged': 9996,
#  'charismatic': 3386,
#  'nipar': 47217,
#  'matchstick': 78128,
#  'joan': 1817,
#  'halo': 28100,
#  'denom': 77457,
#  'accounted': 20233,
#  "babbage's": 34528,
#  'laziest': 39806,
#  'uktv': 72364,
#  'lamo': 64120,
#  'genius': 1259,
#  "winners'": 82607,
#  'crappy': 2133,
#  'encino': 80360,
#  "anthropologist's": 58807,
#  'grabber': 30090,
#  'there´s': 50503,
#  'sobieski': 67194,
#  'gostoso': 47546,
#  'explitive': 55445,
#  "doe's": 41120,
#  'unfair': 5090,
#  'hoof': 31358,
#  'shapes': 10523,
#  'guesswork': 85046,
#  'athol': 42199,
#  'philip': 3057,
#  "'slick'": 56060,
#  'bay': 4775,
#  "'haunting": 58204,
#  'irascible': 20443,
#  "grammar's": 67930,
#  'favourites': 7479,
#  'outrageousness': 28541,
#  'ferula': 50123,
#  'tristesse': 41327,
#  'unibomber': 75627,
#  'ambitions': 7124,
#  "we're": 1103,
#  "minute's": 45060,
#  'storm': 3159,
#  'journeyman': 36894,
#  'atm': 50547,
#  "'sympathetic'": 72010,
#  'yellower': 83220,
#  'ceylonese': 62784,
#  'vernacular': 20892,
#  '65m': 78154,
#  'tenth': 14258,
#  'xxx2': 61491,
#  'harlins': 44322,
#  "general's": 20935,
#  'alla': 30228,
#  'cuarón': 29518,
#  'lori': 15114,
#  'errs': 48239,
#  'rovner': 54503,
#  "'cabin": 37932,
#  "fontana's": 48532,
#  'showtime': 9742,
#  'brundage': 51995,
#  'mouse': 2911,
#  'delusional': 12767,
#  'raliegh': 47026,
#  'doppelganger': 12852,
#  'runner': 5805,
#  'kinnear': 6829,
#  'duddley': 67013,
#  "tenderfoot's": 76056,
#  'finer': 14996,
#  'ages': 2085,
#  'superbabies': 32223,
#  'vahtang': 58919,
#  'jonny': 12956,
#  '£20': 27701,
#  "cave'": 50937,
#  'crowell': 77050,
#  'shawlee': 50487,
#  'lilies': 17569,
#  'anesthesiologist': 54424,
#  'conformists': 63453,
#  'kerkour': 85741,
#  "authorities'": 85586,
#  'oscillate': 68671,
#  'lafontaine': 74819,
#  'flics': 55784,
#  'fatherliness': 79561,
#  'newsradio': 76172,
#  'silsby': 43560,
#  'peal': 49628,
#  'musician’s': 76192,
#  'knuckling': 43752,
#  'ga': 19695,
#  "hazare's": 83602,
#  'hesitancies': 54874,
#  'whammy': 25990,
#  'overthrown': 34379,
#  'khrushchev': 44964,
#  'goelz': 79054,
#  'doubtless': 14321,
#  'alcides': 52877,
#  'sweatshops': 49108,
#  'sensationalist': 27101,
#  'absurd\x85': 82920,
#  'injustices': 18882,
#  'meters': 17006,
#  "mahoney's": 85596,
#  'flaunts': 78847,
#  'untwining': 75620,
#  "instrumental's": 68992,
#  'see': 64,
#  'courtyard': 16429,
#  'mana': 61309,
#  'brioche': 43404,
#  'pubes': 82738,
#  'supervised': 31777,
#  'weinberg': 30188,
#  'frakes': 20106,
#  'grunting': 27529,
#  'constructive': 12711,
#  'unmated': 77058,
#  'thomas': 2099,
#  'hanzo': 8768,
#  'bisexuality': 51742,
#  "koestler's": 58956,
#  'korte': 51505,
#  'bluesy': 50159,
#  'fume': 48623,
#  "'thing'": 51496,
#  'awarding': 25634,
#  'lords': 11548,
#  'authorizing': 71370,
#  'justifiably': 14689,
#  '93': 15436,
#  'kristine': 26733,
#  'innovator': 38791,
#  'tripwires': 71189,
#  'capitaine': 58011,
#  'gianni': 27397,
#  'bullseye': 26489,
#  'peque': 59755,
#  'caving': 72006,
#  'wast': 38555,
#  'riproaring': 80841,
#  'adroit': 30091,
#  'fazes': 63573,
#  'understatedly': 46568,
#  'uxb': 76220,
#  'suceeded': 79603,
#  'minogoue': 70147,
#  'logo': 10046,
#  'breakingly': 40072,
#  'tarrant': 68241,
#  'viewed': 2392,
#  'disrupts': 30102,
#  'grooved': 87068,
#  'tactlessly': 71144,
#  "'dillinger'": 23534,
#  'sleepless': 15437,
#  'streamline': 24687,
#  'saurious': 61360,
#  "amc's": 43766,
#  'sovjet': 62087,
#  "'queen": 51681,
#  'pagemaster': 76535,
#  'sacrificies': 86717,
#  'lucas': 3648,
#  'ribsi': 60110,
#  'idris': 31585,
#  'pappas': 14659,
#  'expounds': 32053,
#  'forty': 4209,
#  'recalled': 14030,
#  'tragically': 10800,
#  'afficionado': 58593,
#  'chide': 84162,
#  'assemblage': 49043,
#  'manmade': 61113,
#  'referent': 73969,
#  'dolphins': 28815,
#  'clandestinely': 51649,
#  "situation'sung": 62366,
#  'consents': 46494,
#  "lange's": 42181,
#  'notwithstanding': 8783,
#  "victor's": 19123,
#  'medicos': 80979,
#  'catwoman': 15713,
#  'suitcases': 46570,
#  'maths': 28511,
#  'nibble': 66246,
#  'creepfest': 58208,
#  'mcfarland': 57068,
#  'squashed': 27909,
#  'land\x85': 75034,
#  'lucinda': 31945,
#  'goomba': 70552,
#  'alejandro': 12616,
#  'leaf': 14126,
#  'tinsletown': 87681,
#  'karaca': 86832,
#  'sniffing': 13693,
#  'flagstaff': 48435,
#  "katsuhito's": 56503,
#  'avonlea': 44328,
#  '60ies': 59027,
#  'jazz': 3979,
#  'tapers': 86082,
#  'shatta': 86724,
#  'impalings': 80951,
#  'fot': 47848,
#  'frivolity': 30866,
#  "scenester's": 79126,
#  'aligning': 67806,
#  'crowded': 8426,
#  'synapse': 22170,
#  'unmask': 33207,
#  'schelsinger': 73620,
#  'relapses': 41721,
#  'axed': 23919,
#  "pocket'": 72999,
#  'confinement': 21408,
#  'retardate': 53816,
#  'tallahassee': 60323,
#  "adela's": 64611,
#  'removed': 4023,
#  "'thunderbirds": 55042,
#  'sondergaard': 86938,
#  'kirkland': 13295,
#  'greaser': 35869,
#  'fritz': 8005,
#  'anchoring': 44114,
#  'dipstick': 85530,
#  'indicator': 16586,
#  'televised': 12450,
#  'tua': 77362,
#  'pin': 5009,
#  'substituted': 17264,
#  'melvyn': 6594,
#  "'original'": 31049,
#  'hebrews': 27449,
#  'cruising': 21169,
#  '1909': 29773,
#  "goldwyn's": 42552,
#  '“food': 80045,
#  "rw's": 53055,
#  'steadfast': 29121,
#  'jacques': 6987,
#  "genre's": 15768,
#  'hilton': 8789,
#  "surgery'": 54405,
#  'fieriness': 69181,
#  'sharon': 5294,
#  'curvature': 66720,
#  'morley': 18493,
#  'perishing': 56101,
#  'eulogized': 53426,
#  'brutti': 69646,
#  'ups': 1966,
#  'bodices': 51246,
#  'orchestrated': 13970,
#  'hemolytic': 58177,
#  'vengeance': 4543,
#  'seidls': 74009,
#  'putzing': 66577,
#  'émigré': 28225,
#  'movie\x97because': 78988,
#  'cozies': 82689,
#  'prevailing': 16864,
#  "'fatty'": 65231,
#  'farentino': 48412,
#  'moves': 1099,
#  "shining'": 51900,
#  'minted': 44691,
#  'shakedown': 38932,
#  'unspeakably': 23037,
#  'hut': 15733,
#  'macdowel': 76891,
#  'frogmarched': 75882,
#  'nana’s': 50064,
#  'balkanic': 52393,
#  'msr': 78310,
#  'rupee': 74082,
#  'strap': 27233,
#  'minstrel': 18292,
#  'arthropods': 80371,
#  'redressed': 72604,
#  'procurator': 87074,
#  'woodchuck': 46972,
#  'clears': 29615,
#  'hurry': 8602,
#  'underplayed': 23152,
#  'graduates': 14345,
#  'slugging': 39154,
#  'capucines': 67892,
#  'insightfulness': 84557,
#  'correspondent': 29482,
#  'alpert': 43029,
#  'ramgarh': 52508,
#  'currents': 21891,
#  'iconic': 5587,
#  'hardcover': 36168,
#  'dave': 3830,
#  'pou': 37951,
#  'spaceport': 78329,
#  'facilitator': 28579,
#  'wrestled': 39955,
#  'fishwife': 66815,
#  "spierlberg's": 75665,
#  'foxx': 5785,
#  "bible's": 77714,
#  "'classified'": 58492,
#  'populated': 6834,
#  'find': 166,
#  'lechers': 66106,
#  'rushing': 12954,
#  'loused': 44839,
#  'mithun': 64482,
#  'junge': 26449,
#  'modus': 29664,
#  'otoko': 55558,
#  'revues': 64906,
#  'shakespeares': 65492,
#  'thrall': 51540,
#  'dainiken': 58326,
#  'imdb': 896,
#  'wiley': 24536,
#  "watching'": 78213,
#  'setpiece': 61340,
#  "'paris": 22290,
#  'cheerful': 7768,
#  "hdtv's": 74552,
#  'coselli': 56495,
#  'trudged': 47314,
#  'trudges': 47315,
#  'filmometer': 69029,
#  "'course": 85489,
#  'vivah': 9332,
#  'lionsault': 42922,
#  'whatchout': 78721,
#  "'anonymous": 53464,
#  'practice': 4285,
#  'aristocracy': 16968,
#  "hall's": 27451,
#  'plumbed': 45647,
#  'improving': 12178,
#  'trajectory': 22154,
#  'innocuously': 82551,
#  'rodman': 36590,
#  'hollow': 4083,
#  "'well": 28693,
#  'stupa': 83939,
#  'ff2': 62676,
#  "7's": 63773,
#  'dachshunds': 73597,
#  'rycart': 58349,
#  'patti': 18407,
#  "'non": 75506,
#  'jenna': 7257,
#  'laetitia': 66704,
#  'vipers': 50538,
#  'ten': 744,
#  'geometry': 32978,
#  'entertains': 8580,
#  '1861': 34650,
#  'reasoned': 21129,
#  'alok': 17406,
#  'lamppost': 76553,
#  "'boriac": 71403,
#  'frío': 55967,
#  'crap': 592,
#  'venin': 61315,
#  'goro': 40509,
#  'envelope': 11893,
#  'torso': 11982,
#  'qualifications': 21248,
#  'reasonably': 3713,
#  'starters': 7046,
#  "connell's": 53712,
#  'issues': 1338,
#  "je'taime": 37747,
#  'mancuso': 23143,
#  'lodger': 24248,
#  'showstopping': 81550,
#  'detectors': 56425,
#  'massage': 27492,
#  'petrochemical': 77948,
#  'unloaded': 71791,
#  'spratt': 70721,
#  'accosts': 40326,
#  'probaly': 79813,
#  'rapier': 40153,
#  'unruly': 21691,
#  'selbst': 84050,
#  "flippin'": 30757,
#  'reba': 47656,
#  'deteste': 56093,
#  'reeler': 29875,
#  'sternwood': 82492,
#  'lyricism': 33552,
#  'hordes': 12414,
#  "archie's": 49733,
#  'emissary': 45753,
#  'nuttery': 72766,
#  'dobson': 18912,
#  'wet': 4437,
#  "'chip'": 73181,
#  'gael': 23957,
#  'hanpei': 50385,
#  'ratcheting': 36231,
#  'vitality': 14495,
#  "'mask": 77024,
#  'recklessness': 24908,
#  "'contemporary'": 71946,
#  "''after": 64015,
#  'kundera': 28724,
#  'tobin': 25978,
#  'lyubomir': 43607,
#  'dodds': 83848,
#  'karts': 42130,
#  'shootings': 9786,
#  'lust': 4018,
#  'bamboozled': 26246,
#  '04': 36612,
#  'publicdomain': 86177,
#  'immitative': 64375,
#  "cop'": 36863,
#  'notting': 16853,
#  "navigator'": 71064,
#  'banter': 6155,
#  "'most": 47959,
#  'howerver': 72090,
#  'eg': 10830,
#  "montel's": 69903,
#  'broadway': 2136,
#  "'values'": 60786,
#  'antiwar': 44011,
#  'wayon': 73114,
#  'irksome': 22445,
#  'blond': 4381,
#  'scoffing': 35000,
#  'dimwitted': 16340,
#  'dreamlike': 12046,
#  'wiesz': 80927,
#  'civilizing': 49103,
#  'loathed': 18414,
#  'ignore': 2751,
#  'polk': 36095,
#  "dodes'ka": 30957,
#  'bmoviefreak': 83588,
#  'gunfighting': 32765,
#  'synonomous': 66360,
#  'hypocritical': 13711,
#  'tarri': 55761,
#  'bode': 28994,
#  'purposes': 4932,
#  'dorlan': 49004,
#  "piano'": 78981,
#  'prètre': 87303,
#  'keanu': 8646,
#  'write': 898,
#  'chug': 49869,
#  'atmospherically': 30793,
#  'tie': 4225,
#  'differentiate': 17703,
#  'conjoined': 35830,
#  'outdrawing': 69284,
#  "sheep's": 71973,
#  'confidential': 12308,
#  'demolition': 14364,
#  'morone': 56755,
#  'laborers': 33515,
#  'superlguing': 68939,
#  "wrestlemania's": 39565,
#  'superficially': 15433,
#  'bjm': 13624,
#  'indie': 2686,
#  'cleaned': 11034,
#  "hawthorne's": 84145,
#  "'baddies'": 82730,
#  'portions': 8455,
#  'arminass': 61147,
#  "london's": 11452,
#  'booed': 20228,
#  'okish': 53889,
#  "beginning'": 45255,
#  "ma'am": 57605,
#  'ctx': 45274,
#  'learning': 2796,
#  'minuets': 30055,
#  'bashed': 13064,
#  'stridently': 35945,
#  "cliché'd": 76582,
#  "giligan's": 69773,
#  "radio's": 46298,
#  'guileless': 42641,
#  'penalized': 62332,
#  'wolfie': 55039,
#  'ayatollah': 62337,
#  'pincher': 56520,
#  'uninteresting': 2499,
#  'eileen': 11699,
#  'crackerjack': 28465,
#  'murmur': 44817,
#  'kinki': 72728,
#  'meara': 84619,
#  'bangster': 55189,
#  'capper': 36444,
#  'dei': 39008,
#  'treshold': 60409,
#  'proposing': 23819,
#  'instance': 1822,
#  'movie': 17,
#  'torments': 18995,
#  'camera': 367,
#  'clause': 12562,
#  'scctm': 59158,
#  'belinda': 27423,
#  'jay': 3063,
#  'okay\x85so': 66377,
#  'ladder': 5401,
#  'dumbfounded': 19298,
#  "doren's": 47343,
#  '01': 12347,
#  'undertook': 43645,
#  'sinus': 27716,
#  'mclellan': 46162,
#  "deighton's": 80407,
#  'rouveroy': 38668,
#  "'mental": 37342,
#  'mics': 66064,
#  ...}

# %%
rev_idx = {v+3:k for k,v in idx.items()}

# %%
rev_idx
# Out:
# {4: 'the',
#  5: 'and',
#  6: 'a',
#  7: 'of',
#  8: 'to',
#  9: 'is',
#  10: 'br',
#  11: 'in',
#  12: 'it',
#  13: 'i',
#  14: 'this',
#  15: 'that',
#  16: 'was',
#  17: 'as',
#  18: 'for',
#  19: 'with',
#  20: 'movie',
#  21: 'but',
#  22: 'film',
#  23: 'on',
#  24: 'not',
#  25: 'you',
#  26: 'are',
#  27: 'his',
#  28: 'have',
#  29: 'he',
#  30: 'be',
#  31: 'one',
#  32: 'all',
#  33: 'at',
#  34: 'by',
#  35: 'an',
#  36: 'they',
#  37: 'who',
#  38: 'so',
#  39: 'from',
#  40: 'like',
#  41: 'her',
#  42: 'or',
#  43: 'just',
#  44: 'about',
#  45: "it's",
#  46: 'out',
#  47: 'has',
#  48: 'if',
#  49: 'some',
#  50: 'there',
#  51: 'what',
#  52: 'good',
#  53: 'more',
#  54: 'when',
#  55: 'very',
#  56: 'up',
#  57: 'no',
#  58: 'time',
#  59: 'she',
#  60: 'even',
#  61: 'my',
#  62: 'would',
#  63: 'which',
#  64: 'only',
#  65: 'story',
#  66: 'really',
#  67: 'see',
#  68: 'their',
#  69: 'had',
#  70: 'can',
#  71: 'were',
#  72: 'me',
#  73: 'well',
#  74: 'than',
#  75: 'we',
#  76: 'much',
#  77: 'been',
#  78: 'bad',
#  79: 'get',
#  80: 'will',
#  81: 'do',
#  82: 'also',
#  83: 'into',
#  84: 'people',
#  85: 'other',
#  86: 'first',
#  87: 'great',
#  88: 'because',
#  89: 'how',
#  90: 'him',
#  91: 'most',
#  92: "don't",
#  93: 'made',
#  94: 'its',
#  95: 'then',
#  96: 'way',
#  97: 'make',
#  98: 'them',
#  99: 'too',
#  100: 'could',
#  101: 'any',
#  102: 'movies',
#  103: 'after',
#  104: 'think',
#  105: 'characters',
#  106: 'watch',
#  107: 'two',
#  108: 'films',
#  109: 'character',
#  110: 'seen',
#  111: 'many',
#  112: 'being',
#  113: 'life',
#  114: 'plot',
#  115: 'never',
#  116: 'acting',
#  117: 'little',
#  118: 'best',
#  119: 'love',
#  120: 'over',
#  121: 'where',
#  122: 'did',
#  123: 'show',
#  124: 'know',
#  125: 'off',
#  126: 'ever',
#  127: 'does',
#  128: 'better',
#  129: 'your',
#  130: 'end',
#  131: 'still',
#  132: 'man',
#  133: 'here',
#  134: 'these',
#  135: 'say',
#  136: 'scene',
#  137: 'while',
#  138: 'why',
#  139: 'scenes',
#  140: 'go',
#  141: 'such',
#  142: 'something',
#  143: 'through',
#  144: 'should',
#  145: 'back',
#  146: "i'm",
#  147: 'real',
#  148: 'those',
#  149: 'watching',
#  150: 'now',
#  151: 'though',
#  152: "doesn't",
#  153: 'years',
#  154: 'old',
#  155: 'thing',
#  156: 'actors',
#  157: 'work',
#  158: '10',
#  159: 'before',
#  160: 'another',
#  161: "didn't",
#  162: 'new',
#  163: 'funny',
#  164: 'nothing',
#  165: 'actually',
#  166: 'makes',
#  167: 'director',
#  168: 'look',
#  169: 'find',
#  170: 'going',
#  171: 'few',
#  172: 'same',
#  173: 'part',
#  174: 'again',
#  175: 'every',
#  176: 'lot',
#  177: 'cast',
#  178: 'us',
#  179: 'quite',
#  180: 'down',
#  181: 'want',
#  182: 'world',
#  183: 'things',
#  184: 'pretty',
#  185: 'young',
#  186: 'seems',
#  187: 'around',
#  188: 'got',
#  189: 'horror',
#  190: 'however',
#  191: "can't",
#  192: 'fact',
#  193: 'take',
#  194: 'big',
#  195: 'enough',
#  196: 'long',
#  197: 'thought',
#  198: "that's",
#  199: 'both',
#  200: 'between',
#  201: 'series',
#  202: 'give',
#  203: 'may',
#  204: 'original',
#  205: 'own',
#  206: 'action',
#  207: "i've",
#  208: 'right',
#  209: 'without',
#  210: 'always',
#  211: 'times',
#  212: 'comedy',
#  213: 'point',
#  214: 'gets',
#  215: 'must',
#  216: 'come',
#  217: 'role',
#  218: "isn't",
#  219: 'saw',
#  220: 'almost',
#  221: 'interesting',
#  222: 'least',
#  223: 'family',
#  224: 'done',
#  225: "there's",
#  226: 'whole',
#  227: 'bit',
#  228: 'music',
#  229: 'script',
#  230: 'far',
#  231: 'making',
#  232: 'guy',
#  233: 'anything',
#  234: 'minutes',
#  235: 'feel',
#  236: 'last',
#  237: 'since',
#  238: 'might',
#  239: 'performance',
#  240: "he's",
#  241: '2',
#  242: 'probably',
#  243: 'kind',
#  244: 'am',
#  245: 'away',
#  246: 'yet',
#  247: 'rather',
#  248: 'tv',
#  249: 'worst',
#  250: 'girl',
#  251: 'day',
#  252: 'sure',
#  253: 'fun',
#  254: 'hard',
#  255: 'woman',
#  256: 'played',
#  257: 'each',
#  258: 'found',
#  259: 'anyone',
#  260: 'having',
#  261: 'although',
#  262: 'especially',
#  263: 'our',
#  264: 'believe',
#  265: 'course',
#  266: 'comes',
#  267: 'looking',
#  268: 'screen',
#  269: 'trying',
#  270: 'set',
#  271: 'goes',
#  272: 'looks',
#  273: 'place',
#  274: 'book',
#  275: 'different',
#  276: 'put',
#  277: 'ending',
#  278: 'money',
#  279: 'maybe',
#  280: 'once',
#  281: 'sense',
#  282: 'reason',
#  283: 'true',
#  284: 'actor',
#  285: 'everything',
#  286: "wasn't",
#  287: 'shows',
#  288: 'dvd',
#  289: 'three',
#  290: 'worth',
#  291: 'year',
#  292: 'job',
#  293: 'main',
#  294: 'someone',
#  295: 'together',
#  296: 'watched',
#  297: 'play',
#  298: 'american',
#  299: 'plays',
#  300: '1',
#  301: 'said',
#  302: 'effects',
#  303: 'later',
#  304: 'takes',
#  305: 'instead',
#  306: 'seem',
#  307: 'beautiful',
#  308: 'john',
#  309: 'himself',
#  310: 'version',
#  311: 'audience',
#  312: 'high',
#  313: 'house',
#  314: 'night',
#  315: 'during',
#  316: 'everyone',
#  317: 'left',
#  318: 'special',
#  319: 'seeing',
#  320: 'half',
#  321: 'excellent',
#  322: 'wife',
#  323: 'star',
#  324: 'shot',
#  325: 'war',
#  326: 'idea',
#  327: 'nice',
#  328: 'black',
#  329: 'less',
#  330: 'mind',
#  331: 'simply',
#  332: 'read',
#  333: 'second',
#  334: 'else',
#  335: "you're",
#  336: 'father',
#  337: 'fan',
#  338: 'poor',
#  339: 'help',
#  340: 'completely',
#  341: 'death',
#  342: '3',
#  343: 'used',
#  344: 'home',
#  345: 'either',
#  346: 'short',
#  347: 'line',
#  348: 'given',
#  349: 'men',
#  350: 'top',
#  351: 'dead',
#  352: 'budget',
#  353: 'try',
#  354: 'performances',
#  355: 'wrong',
#  356: 'classic',
#  357: 'boring',
#  358: 'enjoy',
#  359: 'need',
#  360: 'rest',
#  361: 'use',
#  362: 'kids',
#  363: 'hollywood',
#  364: 'low',
#  365: 'production',
#  366: 'until',
#  367: 'along',
#  368: 'full',
#  369: 'friends',
#  370: 'camera',
#  371: 'truly',
#  372: 'women',
#  373: 'awful',
#  374: 'video',
#  375: 'next',
#  376: 'tell',
#  377: 'remember',
#  378: 'couple',
#  379: 'stupid',
#  380: 'start',
#  381: 'stars',
#  382: 'perhaps',
#  383: 'sex',
#  384: 'mean',
#  385: 'came',
#  386: 'recommend',
#  387: 'let',
#  388: 'moments',
#  389: 'wonderful',
#  390: 'episode',
#  391: 'understand',
#  392: 'small',
#  393: 'face',
#  394: 'terrible',
#  395: 'playing',
#  396: 'school',
#  397: 'getting',
#  398: 'written',
#  399: 'doing',
#  400: 'often',
#  401: 'keep',
#  402: 'early',
#  403: 'name',
#  404: 'perfect',
#  405: 'style',
#  406: 'human',
#  407: 'definitely',
#  408: 'gives',
#  409: 'others',
#  410: 'itself',
#  411: 'lines',
#  412: 'live',
#  413: 'become',
#  414: 'dialogue',
#  415: 'person',
#  416: 'lost',
#  417: 'finally',
#  418: 'piece',
#  419: 'head',
#  420: 'case',
#  421: 'felt',
#  422: 'yes',
#  423: 'liked',
#  424: 'supposed',
#  425: 'title',
#  426: "couldn't",
#  427: 'absolutely',
#  428: 'white',
#  429: 'against',
#  430: 'boy',
#  431: 'picture',
#  432: 'sort',
#  433: 'worse',
#  434: 'certainly',
#  435: 'went',
#  436: 'entire',
#  437: 'waste',
#  438: 'cinema',
#  439: 'problem',
#  440: 'hope',
#  441: 'entertaining',
#  442: "she's",
#  443: 'mr',
#  444: 'overall',
#  445: 'evil',
#  446: 'called',
#  447: 'loved',
#  448: 'based',
#  449: 'oh',
#  450: 'several',
#  451: 'fans',
#  452: 'mother',
#  453: 'drama',
#  454: 'beginning',
#  455: 'killer',
#  456: 'lives',
#  457: '5',
#  458: 'direction',
#  459: 'care',
#  460: 'already',
#  461: 'becomes',
#  462: 'laugh',
#  463: 'example',
#  464: 'friend',
#  465: 'dark',
#  466: 'despite',
#  467: 'under',
#  468: 'seemed',
#  469: 'throughout',
#  470: '4',
#  471: 'turn',
#  472: 'unfortunately',
#  473: 'wanted',
#  474: "i'd",
#  475: '\x96',
#  476: 'children',
#  477: 'final',
#  478: 'fine',
#  479: 'history',
#  480: 'amazing',
#  481: 'sound',
#  482: 'guess',
#  483: 'heart',
#  484: 'totally',
#  485: 'lead',
#  486: 'humor',
#  487: 'writing',
#  488: 'michael',
#  489: 'quality',
#  490: "you'll",
#  491: 'close',
#  492: 'son',
#  493: 'guys',
#  494: 'wants',
#  495: 'works',
#  496: 'behind',
#  497: 'tries',
#  498: 'art',
#  499: 'side',
#  500: 'game',
#  501: 'past',
#  502: 'able',
#  503: 'b',
#  504: 'days',
#  505: 'turns',
#  506: 'child',
#  507: "they're",
#  508: 'hand',
#  509: 'flick',
#  510: 'enjoyed',
#  511: 'act',
#  512: 'genre',
#  513: 'town',
#  514: 'favorite',
#  515: 'soon',
#  516: 'kill',
#  517: 'starts',
#  518: 'sometimes',
#  519: 'car',
#  520: 'gave',
#  521: 'run',
#  522: 'late',
#  523: 'eyes',
#  524: 'actress',
#  525: 'etc',
#  526: 'directed',
#  527: 'horrible',
#  528: "won't",
#  529: 'viewer',
#  530: 'brilliant',
#  531: 'parts',
#  532: 'self',
#  533: 'themselves',
#  534: 'hour',
#  535: 'expect',
#  536: 'thinking',
#  537: 'stories',
#  538: 'stuff',
#  539: 'girls',
#  540: 'obviously',
#  541: 'blood',
#  542: 'decent',
#  543: 'city',
#  544: 'voice',
#  545: 'highly',
#  546: 'myself',
#  547: 'feeling',
#  548: 'fight',
#  549: 'except',
#  550: 'slow',
#  551: 'matter',
#  552: 'type',
#  553: 'anyway',
#  554: 'kid',
#  555: 'roles',
#  556: 'killed',
#  557: 'heard',
#  558: 'god',
#  559: 'age',
#  560: 'says',
#  561: 'moment',
#  562: 'took',
#  563: 'leave',
#  564: 'writer',
#  565: 'strong',
#  566: 'cannot',
#  567: 'violence',
#  568: 'police',
#  569: 'hit',
#  570: 'stop',
#  571: 'happens',
#  572: 'particularly',
#  573: 'known',
#  574: 'involved',
#  575: 'happened',
#  576: 'extremely',
#  577: 'daughter',
#  578: 'obvious',
#  579: 'told',
#  580: 'chance',
#  581: 'living',
#  582: 'coming',
#  583: 'lack',
#  584: 'alone',
#  585: 'experience',
#  586: "wouldn't",
#  587: 'including',
#  588: 'murder',
#  589: 'attempt',
#  590: 's',
#  591: 'please',
#  592: 'james',
#  593: 'happen',
#  594: 'wonder',
#  595: 'crap',
#  596: 'ago',
#  597: 'brother',
#  598: "film's",
#  599: 'gore',
#  600: 'none',
#  601: 'complete',
#  602: 'interest',
#  603: 'score',
#  604: 'group',
#  605: 'cut',
#  606: 'simple',
#  607: 'save',
#  608: 'ok',
#  609: 'hell',
#  610: 'looked',
#  611: 'career',
#  612: 'number',
#  613: 'song',
#  614: 'possible',
#  615: 'seriously',
#  616: 'annoying',
#  617: 'shown',
#  618: 'exactly',
#  619: 'sad',
#  620: 'running',
#  621: 'musical',
#  622: 'serious',
#  623: 'taken',
#  624: 'yourself',
#  625: 'whose',
#  626: 'released',
#  627: 'cinematography',
#  628: 'david',
#  629: 'scary',
#  630: 'ends',
#  631: 'english',
#  632: 'hero',
#  633: 'usually',
#  634: 'hours',
#  635: 'reality',
#  636: 'opening',
#  637: "i'll",
#  638: 'across',
#  639: 'today',
#  640: 'jokes',
#  641: 'light',
#  642: 'hilarious',
#  643: 'somewhat',
#  644: 'usual',
#  645: 'started',
#  646: 'cool',
#  647: 'ridiculous',
#  648: 'body',
#  649: 'relationship',
#  650: 'view',
#  651: 'level',
#  652: 'opinion',
#  653: 'change',
#  654: 'happy',
#  655: 'middle',
#  656: 'taking',
#  657: 'wish',
#  658: 'husband',
#  659: 'finds',
#  660: 'saying',
#  661: 'order',
#  662: 'talking',
#  663: 'ones',
#  664: 'documentary',
#  665: 'shots',
#  666: 'huge',
#  667: 'novel',
#  668: 'female',
#  669: 'mostly',
#  670: 'robert',
#  671: 'power',
#  672: 'episodes',
#  673: 'room',
#  674: 'important',
#  675: 'rating',
#  676: 'talent',
#  677: 'five',
#  678: 'major',
#  679: 'turned',
#  680: 'strange',
#  681: 'word',
#  682: 'modern',
#  683: 'call',
#  684: 'apparently',
#  685: 'disappointed',
#  686: 'single',
#  687: 'events',
#  688: 'due',
#  689: 'four',
#  690: 'songs',
#  691: 'basically',
#  692: 'attention',
#  693: '7',
#  694: 'knows',
#  695: 'clearly',
#  696: 'supporting',
#  697: 'knew',
#  698: 'british',
#  699: 'television',
#  700: 'comic',
#  701: 'non',
#  702: 'fast',
#  703: 'earth',
#  704: 'country',
#  705: 'future',
#  706: 'cheap',
#  707: 'class',
#  708: 'thriller',
#  709: '8',
#  710: 'silly',
#  711: 'king',
#  712: 'problems',
#  713: "aren't",
#  714: 'easily',
#  715: 'words',
#  716: 'tells',
#  717: 'miss',
#  718: 'jack',
#  719: 'local',
#  720: 'sequence',
#  721: 'bring',
#  722: 'entertainment',
#  723: 'paul',
#  724: 'beyond',
#  725: 'upon',
#  726: 'whether',
#  727: 'predictable',
#  728: 'moving',
#  729: 'similar',
#  730: 'straight',
#  731: 'romantic',
#  732: 'sets',
#  733: 'review',
#  734: 'falls',
#  735: 'oscar',
#  736: 'mystery',
#  737: 'enjoyable',
#  738: 'needs',
#  739: 'appears',
#  740: 'talk',
#  741: 'rock',
#  742: 'george',
#  743: 'giving',
#  744: 'eye',
#  745: 'richard',
#  746: 'within',
#  747: 'ten',
#  748: 'animation',
#  749: 'message',
#  750: 'theater',
#  751: 'near',
#  752: 'above',
#  753: 'dull',
#  754: 'nearly',
#  755: 'sequel',
#  756: 'theme',
#  757: 'points',
#  758: "'",
#  759: 'stand',
#  760: 'mention',
#  761: 'lady',
#  762: 'bunch',
#  763: 'add',
#  764: 'feels',
#  765: 'herself',
#  766: 'release',
#  767: 'red',
#  768: 'team',
#  769: 'storyline',
#  770: 'surprised',
#  771: 'ways',
#  772: 'using',
#  773: 'named',
#  774: "haven't",
#  775: 'lots',
#  776: 'easy',
#  777: 'fantastic',
#  778: 'begins',
#  779: 'actual',
#  780: 'working',
#  781: 'effort',
#  782: 'york',
#  783: 'die',
#  784: 'hate',
#  785: 'french',
#  786: 'minute',
#  787: 'tale',
#  788: 'clear',
#  789: 'stay',
#  790: '9',
#  791: 'elements',
#  792: 'feature',
#  793: 'among',
#  794: 'follow',
#  795: 'comments',
#  796: 're',
#  797: 'viewers',
#  798: 'avoid',
#  799: 'sister',
#  800: 'showing',
#  801: 'typical',
#  802: 'editing',
#  803: "what's",
#  804: 'famous',
#  805: 'tried',
#  806: 'sorry',
#  807: 'dialog',
#  808: 'check',
#  809: 'fall',
#  810: 'period',
#  811: 'season',
#  812: 'form',
#  813: 'certain',
#  814: 'filmed',
#  815: 'weak',
#  816: 'soundtrack',
#  817: 'means',
#  818: 'buy',
#  819: 'material',
#  820: 'somehow',
#  821: 'realistic',
#  822: 'figure',
#  823: 'crime',
#  824: 'doubt',
#  825: 'gone',
#  826: 'peter',
#  827: 'tom',
#  828: 'kept',
#  829: 'viewing',
#  830: 't',
#  831: 'general',
#  832: 'leads',
#  833: 'greatest',
#  834: 'space',
#  835: 'lame',
#  836: 'suspense',
#  837: 'dance',
#  838: 'imagine',
#  839: 'brought',
#  840: 'third',
#  841: 'atmosphere',
#  842: 'hear',
#  843: 'particular',
#  844: 'sequences',
#  845: 'whatever',
#  846: 'parents',
#  847: 'move',
#  848: 'lee',
#  849: 'indeed',
#  850: 'learn',
#  851: 'rent',
#  852: 'de',
#  853: 'eventually',
#  854: 'note',
#  855: 'deal',
#  856: 'average',
#  857: 'reviews',
#  858: 'wait',
#  859: 'forget',
#  860: 'japanese',
#  861: 'sexual',
#  862: 'poorly',
#  863: 'premise',
#  864: 'okay',
#  865: 'zombie',
#  866: 'surprise',
#  867: 'believable',
#  868: 'stage',
#  869: 'possibly',
#  870: 'sit',
#  871: "who's",
#  872: 'decided',
#  873: 'expected',
#  874: "you've",
#  875: 'subject',
#  876: 'nature',
#  877: 'became',
#  878: 'difficult',
#  879: 'free',
#  880: 'killing',
#  881: 'screenplay',
#  882: 'truth',
#  883: 'romance',
#  884: 'dr',
#  885: 'nor',
#  886: 'reading',
#  887: 'needed',
#  888: 'question',
#  889: 'leaves',
#  890: 'street',
#  891: '20',
#  892: 'meets',
#  893: 'hot',
#  894: 'unless',
#  895: 'begin',
#  896: 'baby',
#  897: 'superb',
#  898: 'credits',
#  899: 'imdb',
#  900: 'otherwise',
#  901: 'write',
#  902: 'shame',
#  903: "let's",
#  904: 'situation',
#  905: 'dramatic',
#  906: 'memorable',
#  907: 'directors',
#  908: 'earlier',
#  909: 'meet',
#  910: 'disney',
#  911: 'open',
#  912: 'dog',
#  913: 'badly',
#  914: 'joe',
#  915: 'male',
#  916: 'weird',
#  917: 'acted',
#  918: 'forced',
#  919: 'laughs',
#  920: 'sci',
#  921: 'emotional',
#  922: 'older',
#  923: 'realize',
#  924: 'fi',
#  925: 'dream',
#  926: 'society',
#  927: 'writers',
#  928: 'interested',
#  929: 'footage',
#  930: 'forward',
#  931: 'comment',
#  932: 'crazy',
#  933: 'deep',
#  934: 'sounds',
#  935: 'plus',
#  936: 'beauty',
#  937: 'whom',
#  938: 'america',
#  939: 'fantasy',
#  940: 'directing',
#  941: 'keeps',
#  942: 'ask',
#  943: 'development',
#  944: 'features',
#  945: 'air',
#  946: 'quickly',
#  947: 'mess',
#  948: 'creepy',
#  949: 'towards',
#  950: 'perfectly',
#  951: 'mark',
#  952: 'worked',
#  953: 'box',
#  954: 'cheesy',
#  955: 'unique',
#  956: 'setting',
#  957: 'hands',
#  958: 'plenty',
#  959: 'result',
#  960: 'previous',
#  961: 'brings',
#  962: 'effect',
#  963: 'e',
#  964: 'total',
#  965: 'personal',
#  966: 'incredibly',
#  967: 'rate',
#  968: 'fire',
#  969: 'monster',
#  970: 'business',
#  971: 'leading',
#  972: 'apart',
#  973: 'casting',
#  974: 'admit',
#  975: 'joke',
#  976: 'powerful',
#  977: 'appear',
#  978: 'background',
#  979: 'telling',
#  980: 'girlfriend',
#  981: 'meant',
#  982: 'christmas',
#  983: 'hardly',
#  984: 'present',
#  985: 'battle',
#  986: 'potential',
#  987: 'create',
#  988: 'bill',
#  989: 'break',
#  990: 'pay',
#  991: 'masterpiece',
#  992: 'gay',
#  993: 'political',
#  994: 'return',
#  995: 'dumb',
#  996: 'fails',
#  997: 'fighting',
#  998: 'various',
#  999: 'era',
#  1000: 'portrayed',
#  1001: 'co',
#  1002: 'cop',
#  1003: 'secret',
#  ...}

# %%
rev_idx[0] = 'padding_char'
rev_idx[1] = 'start_char'
rev_idx[2] = 'oov_char'
rev_idx[3] = 'unk_char'

# %%
rev_idx[3]
# Out:
# 'unk_char'

# %%
y_train[0]
# Out:
# 1

# %%
example_review = ' '.join([rev_idx[word] for word in X_train[0]])
example_review
# Out:
# "start_char this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert redford's is an amazing actor and now the same being director norman's father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for retail and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also congratulations to the two little boy's that played the part's of norman and paul they were just brilliant children are often left out of the praising list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
len(X_train[0])
# Out:
# 218

# %%
len(X_train[1])
# Out:
# 189

# %%
len(X_train[2])
# Out:
# 141

# %%
len(X_train[3])
# Out:
# 550

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.layers import LSTM

# %%
maxlen = 100

X_train_pad = pad_sequences(X_train, maxlen=maxlen)
X_test_pad = pad_sequences(X_test, maxlen=maxlen)

# %%
X_train.shape
# Out:
# (25000,)

# %%
X_train_pad[0]
# Out:
# array([ 1415,    33,     6,    22,    12,   215,    28,    77,    52,
#            5,    14,   407,    16,    82, 10311,     8,     4,   107,
#          117,  5952,    15,   256,     4, 31050,     7,  3766,     5,
#          723,    36,    71,    43,   530,   476,    26,   400,   317,
#           46,     7,     4, 12118,  1029,    13,   104,    88,     4,
#          381,    15,   297,    98,    32,  2071,    56,    26,   141,
#            6,   194,  7486,    18,     4,   226,    22,    21,   134,
#          476,    26,   480,     5,   144,    30,  5535,    18,    51,
#           36,    28,   224,    92,    25,   104,     4,   226,    65,
#           16,    38,  1334,    88,    12,    16,   283,     5,    16,
#         4472,   113,   103,    32,    15,    16,  5345,    19,   178,    32], dtype=int32)

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  31050,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  12118,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
max_features = max([max(x) for x in X_train_pad] + 
                   [max(x) for x in X_test_pad]) + 1
max_features
# Out:
# 88587

# %%
y_train
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train_pad, y_train,
          batch_size=32,
          epochs=2,
          validation_split=0.3)
# Out:
# Train on 17500 samples, validate on 7500 samples
# Epoch 1/2
# 17500/17500 [==============================] - 341s - loss: 0.4826 - acc: 0.7672 - val_loss: 0.4055 - val_acc: 0.8195
# Epoch 2/2
# 17500/17500 [==============================] - 308s - loss: 0.2684 - acc: 0.8939 - val_loss: 0.3955 - val_acc: 0.8316

# %%
score, acc = model.evaluate(X_test_pad, y_test)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 25000/25000 [==============================] - 49s
# Test score: 0.408025233679
# Test accuracy: 0.82544

# %% [markdown]
# ## Exercise 1
#
# - Reload the IMDB data keeping only the first 20000 most common words
# - pad the reviews to a shorter length (eg. 70 or 80), this time make sure you keep the first part of the review if it's longer than the maximum length
# - re run the model (remember to set max_features correctly)
# - does it train faster this time?
# - do you get a better performance?

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data('/tmp/imdb.npz',
                                                      num_words=20000,
                                                      skip_top=0,
                                                      maxlen=None,
                                                      start_char=1,
                                                      oov_char=2,
                                                      index_from=3)

# %%
maxlen = 80

X_train_pad = pad_sequences(X_train, maxlen=maxlen)
X_test_pad = pad_sequences(X_test, maxlen=maxlen)

# %%
max_features = max([max(x) for x in X_train_pad] + 
                   [max(x) for x in X_test_pad]) + 1
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(X_train_pad, y_train,
          batch_size=32,
          epochs=2,
          validation_split=0.3)
score, acc = model.evaluate(X_test_pad, y_test)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Train on 17500 samples, validate on 7500 samples
# Epoch 1/2
# 17500/17500 [==============================] - 159s - loss: 0.4855 - acc: 0.7665 - val_loss: 0.4231 - val_acc: 0.8076
# Epoch 2/2
# 17500/17500 [==============================] - 154s - loss: 0.2979 - acc: 0.8797 - val_loss: 0.4022 - val_acc: 0.8121
# 24992/25000 [============================>.] - ETA: 0sTest score: 0.407452223873
# Test accuracy: 0.81452

# %% [markdown]
# ## Exercise 2
#
# - Reload the digits data as above
# - define a function repeated_training_reg_dropout that adds regularization and dropout to a fully connected network
# - compare the performance with/witouth dropout and regularization like we did for batch normalization
# - do you get a better performance?

# %%
digits = load_digits()

# %%
def repeated_training_reg_dropout(X_train,
                      y_train,
                      X_test,
                      y_test,
                      units=512,
                      activation='sigmoid',
                      optimizer='sgd',
                      do_rd=False,
                      epochs=10,
                      repeats=3):
    histories = []
    
    regularlizer = None
    if do_rd:
        regularlizer = 'l2'

    for repeat in range(repeats):
        K.clear_session()

        model = Sequential()
        
        # first fully connected layer            
        model.add(Dense(units,
                        kernel_initializer='normal',
                        activation=activation,
                        kernel_regularizer=regularlizer,
                        input_shape=X_train.shape[1:]))

        # second fully connected layer
        if do_rd:
            model.add(Dropout(0.2))
            
        model.add(Dense(units,
                        kernel_initializer='normal',
                        activation=activation,
                       kernel_regularizer=regularlizer))

        # third fully connected layer
        if do_rd:
            model.add(Dropout(0.2))
            
        model.add(Dense(units,
                        kernel_initializer='normal',
                        activation=activation,
                       kernel_regularizer=regularlizer))

        # output layer
        model.add(Dense(10, activation='softmax'))
        
        model.compile(optimizer,
                      'categorical_crossentropy',
                      metrics=['accuracy'])

        h = model.fit(X_train, y_train,
                      validation_data=(X_test, y_test),
                      epochs=epochs,
                      verbose=0)
        histories.append([h.history['acc'], h.history['val_acc']])
        print(repeat, end=' ')

    histories = np.array(histories)
    
    # calculate mean and standard deviation across repeats:
    mean_acc = histories.mean(axis=0)
    std_acc = histories.std(axis=0)
    print()
    
    return mean_acc[0], std_acc[0], mean_acc[1], std_acc[1]

# %%
X, y = digits.data, digits.target
X_train, X_test, y_train, y_test = train_test_split(X, y_cat,
                                                    test_size=0.3)
mean_acc, std_acc, mean_acc_val, std_acc_val = \
    repeated_training_reg_dropout(X_train, y_train, X_test, y_test, do_rd=False, epochs=30)
# Out:
# 0 1 2

# %%
mean_acc_rd, std_acc_rd, mean_acc_val_rd, std_acc_val_rd = \
    repeated_training_reg_dropout(X_train, y_train, X_test, y_test, do_rd=True, epochs=30)
# Out:
# 0 1 2

# %%
plot_mean_std(mean_acc, std_acc)
plot_mean_std(mean_acc_val, std_acc_val)
plot_mean_std(mean_acc_rd, std_acc_rd)
plot_mean_std(mean_acc_val_rd, std_acc_val_rd)
plt.ylim(0, 1.01)
plt.title("Regularization and Droput Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test', 'Train with Regularization and Dropout', 'Test with Regularlization and Dropout'], loc='best')

# %% [markdown]
# ## Exercise 3
#
# This is a very long and complex exercise, that should give you an idea of a real world scenario. Feel free to look at the solution if you feel lost.
#
# Download and unpack the male/female pictures from [here](https://www.dropbox.com/s/nov493om2jmh2gp/male_female.tgz?dl=0). These images and labels were obtained from [Crowdflower](https://www.crowdflower.com/data-for-everyone/).
#
# Your goal is to build an image classifier that will recognize the gender of a person from pictures.
#
# - Have a look at the directory structure and inspect a couple of pictures
# - Design a model that will take a color image of size 64x64 as input and return a binary output (female=0/male=1)
# - Feel free to introduce any regularization technique in your model (Dropout, Batch Normalization, Weight Regularization)
# - Compile your model with an optimizer of your choice
# - Using `ImageDataGenerator`, define a train generator that will augment your images with some geometric transformations. Feel free to choose the parameters that make sense to you.
# - Define also a test generator, whose only purpose is to rescale the pixels by 1./255
# - use the function `flow_from_directory` to generate batches from the train and test folders. Make sure you set the `target_size` to 64x64.
# - Use the `model.fit_generator` function to fit the model on the batches generated from the ImageDataGenerator. Since you are streaming and augmenting the data in real time you will have to decide how many batches make an epoch and how many epochs you want to run
# - Train your model (you should get to at least 85% accuracy). If training is too slow you can use a cloud hosted notebook to train using a GPU
# - Once you are satisfied with your training, check a few of the misclassified pictures. Are those sensible errors?

# %%
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Activation
from keras.layers import Flatten
from keras.layers import BatchNormalization
K.clear_session()
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', input_shape=(64, 64, 3)))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
trainGenerator = ImageDataGenerator(rescale = 1./255,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               rotation_range = 20,
                               shear_range = 0.3,
                               zoom_range = 0.3,
                               horizontal_flip = True)
train = trainGenerator.flow_from_directory('../data/MaleFemale/train',
                                      target_size = (64, 64),
                                      batch_size = 64,
                                      class_mode = 'binary')
testGenerator = ImageDataGenerator(rescale = 1./255)
test = testGenerator.flow_from_directory('../data/MaleFemale/test',
                                      target_size = (64, 64),
                                      batch_size = 64,
                                      class_mode = 'binary')
# Out:
# Found 11663 images belonging to 2 classes.
# Found 2920 images belonging to 2 classes.

# %%
model.fit_generator(train, epochs=2, verbose=1, steps_per_epoch=182)
# Out:
# Epoch 1/2
# 182/182 [==============================] - 90s - loss: 1.7284 - acc: 0.5599
# Epoch 2/2
# 182/182 [==============================] - 88s - loss: 0.6251 - acc: 0.6623

# %%
from itertools import islice
X_test = []
y_test = []
for ts in islice(test, 50):
    X_test.append(ts[0])
    y_test.append(ts[1])

X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)
y_pred = model.predict_classes(X_test).ravel()
# Out:
# 3168/3176 [============================>.] - ETA: 0s

# %%
np.argwhere(y_test != y_pred).ravel()
# Out:
# array([   1,    4,    5,    6,    9,   19,   24,   29,   30,   33,   34,
#          37,   43,   45,   46,   47,   48,   52,   55,   57,   78,   79,
#          82,   83,   86,   87,   91,   92,   94,  100,  105,  108,  114,
#         116,  117,  121,  123,  124,  125,  126,  128,  130,  134,  136,
#         138,  143,  145,  147,  148,  152,  155,  159,  162,  163,  164,
#         165,  168,  178,  182,  183,  187,  188,  194,  200,  201,  206,
#         209,  212,  214,  215,  216,  217,  219,  220,  226,  233,  235,
#         239,  243,  246,  249,  254,  261,  268,  270,  272,  273,  276,
#         279,  280,  287,  289,  292,  294,  299,  309,  310,  316,  318,
#         321,  327,  329,  330,  331,  334,  336,  337,  340,  344,  345,
#         351,  352,  358,  359,  363,  369,  370,  371,  378,  379,  382,
#         389,  390,  391,  404,  411,  413,  417,  420,  424,  432,  433,
#         434,  435,  436,  438,  444,  445,  447,  448,  450,  452,  455,
#         458,  463,  468,  477,  478,  480,  482,  485,  493,  495,  501,
#         506,  508,  514,  517,  520,  521,  527,  532,  533,  537,  540,
#         549,  550,  551,  554,  558,  561,  565,  566,  567,  569,  578,
#         579,  580,  585,  586,  591,  595,  597,  598,  603,  605,  608,
#         609,  612,  615,  619,  623,  625,  627,  628,  631,  637,  642,
#         645,  650,  651,  654,  656,  657,  658,  663,  665,  667,  670,
#         671,  677,  679,  680,  684,  688,  690,  693,  696,  699,  703,
#         706,  709,  710,  711,  720,  725,  727,  732,  737,  739,  741,
#         743,  747,  760,  762,  763,  765,  768,  770,  771,  772,  773,
#         777,  783,  785,  787,  791,  796,  798,  802,  803,  804,  805,
#         809,  813,  814,  819,  821,  823,  837,  847,  848,  850,  855,
#         859,  863,  865,  869,  874,  876,  877,  878,  882,  884,  886,
#         890,  892,  894,  895,  897,  901,  905,  906,  912,  914,  915,
#         916,  922,  928,  932,  935,  937,  939,  941,  944,  946,  948,
#         950,  952,  953,  957,  958,  960,  963,  965,  967,  968,  971,
#         973,  974,  975,  977,  979,  980,  984,  987,  988,  990,  993,
#         994,  995,  998,  999, 1000, 1003, 1004, 1005, 1006, 1010, 1012,
#        1013, 1017, 1018, 1020, 1025, 1027, 1039, 1041, 1043, 1044, 1046,
#        1047, 1050, 1051, 1053, 1058, 1062, 1063, 1064, 1065, 1069, 1071,
#        1073, 1074, 1076, 1083, 1085, 1092, 1094, 1095, 1096, 1097, 1103,
#        1105, 1109, 1110, 1112, 1114, 1115, 1121, 1123, 1124, 1127, 1128,
#        1129, 1132, 1133, 1134, 1137, 1140, 1144, 1148, 1149, 1151, 1155,
#        1163, 1170, 1171, 1181, 1183, 1199, 1205, 1206, 1211, 1212, 1213,
#        1214, 1215, 1220, 1221, 1229, 1232, 1233, 1234, 1237, 1238, 1243,
#        1253, 1258, 1259, 1263, 1265, 1266, 1269, 1278, 1279, 1284, 1286,
#        1291, 1293, 1294, 1295, 1298, 1305, 1310, 1313, 1322, 1323, 1325,
#        1326, 1327, 1330, 1331, 1332, 1333, 1348, 1351, 1352, 1353, 1355,
#        1358, 1359, 1367, 1372, 1375, 1378, 1389, 1397, 1402, 1404, 1407,
#        1408, 1409, 1417, 1418, 1420, 1422, 1425, 1426, 1427, 1430, 1432,
#        1434, 1436, 1446, 1447, 1449, 1451, 1456, 1458, 1460, 1464, 1466,
#        1467, 1468, 1469, 1471, 1473, 1486, 1489, 1490, 1495, 1499, 1505,
#        1506, 1509, 1511, 1513, 1520, 1527, 1528, 1531, 1533, 1540, 1542,
#        1544, 1545, 1551, 1554, 1555, 1556, 1557, 1558, 1560, 1562, 1565,
#        1569, 1570, 1574, 1586, 1587, 1588, 1589, 1591, 1592, 1593, 1595,
#        1602, 1605, 1609, 1610, 1611, 1614, 1616, 1618, 1621, 1622, 1623,
#        1631, 1632, 1633, 1634, 1638, 1644, 1646, 1651, 1652, 1653, 1657,
#        1661, 1663, 1665, 1667, 1668, 1673, 1674, 1676, 1679, 1687, 1691,
#        1692, 1697, 1698, 1709, 1715, 1718, 1721, 1726, 1728, 1731, 1732,
#        1738, 1740, 1743, 1746, 1747, 1752, 1755, 1759, 1760, 1762, 1764,
#        1767, 1770, 1775, 1778, 1780, 1781, 1788, 1797, 1799, 1800, 1802,
#        1803, 1806, 1811, 1814, 1822, 1823, 1825, 1828, 1838, 1844, 1847,
#        1849, 1854, 1855, 1859, 1863, 1866, 1868, 1870, 1872, 1877, 1879,
#        1880, 1884, 1886, 1887, 1891, 1898, 1901, 1911, 1914, 1916, 1922,
#        1923, 1924, 1931, 1933, 1934, 1935, 1937, 1942, 1948, 1949, 1951,
#        1952, 1953, 1955, 1961, 1963, 1964, 1967, 1987, 1990, 1991, 1992,
#        1996, 1998, 2002, 2013, 2015, 2016, 2023, 2033, 2037, 2043, 2049,
#        2054, 2055, 2059, 2060, 2064, 2066, 2067, 2068, 2080, 2086, 2087,
#        2088, 2096, 2097, 2099, 2117, 2120, 2122, 2125, 2126, 2129, 2130,
#        2136, 2140, 2142, 2147, 2148, 2156, 2158, 2159, 2161, 2166, 2167,
#        2171, 2175, 2176, 2182, 2184, 2188, 2192, 2194, 2202, 2203, 2209,
#        2210, 2212, 2214, 2216, 2218, 2220, 2223, 2227, 2228, 2232, 2235,
#        2237, 2247, 2250, 2267, 2273, 2274, 2276, 2281, 2285, 2288, 2291,
#        2299, 2300, 2303, 2305, 2306, 2307, 2309, 2311, 2315, 2316, 2319,
#        2324, 2328, 2330, 2332, 2338, 2339, 2340, 2342, 2344, 2346, 2348,
#        2356, 2360, 2366, 2374, 2379, 2384, 2386, 2387, 2389, 2392, 2401,
#        2402, 2412, 2421, 2423, 2428, 2431, 2433, 2436, 2439, 2443, 2444,
#        2445, 2446, 2447, 2448, 2452, 2454, 2455, 2458, 2459, 2465, 2466,
#        2467, 2468, 2471, 2475, 2476, 2479, 2481, 2484, 2487, 2489, 2491,
#        2496, 2497, 2498, 2499, 2501, 2502, 2505, 2507, 2509, 2517, 2520,
#        2521, 2526, 2527, 2531, 2533, 2534, 2535, 2537, 2538, 2544, 2551,
#        2554, 2560, 2568, 2573, 2574, 2577, 2578, 2579, 2581, 2587, 2591,
#        2592, 2595, 2597, 2601, 2602, 2604, 2607, 2612, 2613, 2615, 2617,
#        2618, 2620, 2626, 2632, 2636, 2646, 2649, 2656, 2657, 2661, 2662,
#        2665, 2670, 2679, 2682, 2687, 2694, 2695, 2700, 2701, 2705, 2708,
#        2712, 2715, 2719, 2720, 2721, 2723, 2726, 2728, 2731, 2740, 2742,
#        2747, 2748, 2751, 2752, 2755, 2760, 2762, 2764, 2765, 2769, 2771,
#        2772, 2773, 2775, 2777, 2788, 2789, 2790, 2792, 2794, 2799, 2802,
#        2807, 2815, 2820, 2821, 2828, 2830, 2831, 2832, 2834, 2835, 2836,
#        2838, 2843, 2849, 2852, 2853, 2867, 2871, 2875, 2876, 2880, 2883,
#        2884, 2885, 2888, 2890, 2892, 2894, 2912, 2920, 2922, 2923, 2924,
#        2926, 2928, 2931, 2932, 2935, 2940, 2943, 2945, 2948, 2957, 2958,
#        2961, 2968, 2969, 2972, 2978, 2980, 2981, 2982, 2984, 2985, 2986,
#        2987, 2991, 2997, 2998, 3000, 3001, 3008, 3009, 3012, 3014, 3016,
#        3019, 3020, 3022, 3026, 3030, 3032, 3041, 3045, 3050, 3052, 3055,
#        3059, 3060, 3061, 3062, 3063, 3064, 3067, 3072, 3074, 3077, 3081,
#        3088, 3089, 3090, 3091, 3094, 3100, 3108, 3109, 3110, 3115, 3116,
#        3117, 3118, 3122, 3123, 3128, 3130, 3131, 3134, 3137, 3141, 3148,
#        3149, 3152, 3158, 3161, 3175])

# %%
plt.imshow(X_test[19])
